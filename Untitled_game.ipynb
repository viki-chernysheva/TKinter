# %% [markdown]
# # Создание игры «Собери урожай»
# ## Что будет на экране
#
# <table style="border-collapse: collapse; width: 100%; border: 2px solid #ccc; font-family: monospace; font-size: 16px;">
#   <!-- 1 строка: Шапка (Снизу видна линия) -->
#   <tr style="border-bottom: 2px solid #ccc;">
#     <td style="padding: 10px; font-weight: bold; width: 33%;">🍎 СОБЕРИ УРОЖАЙ!</td>
#     <td style="padding: 10px; font-weight: bold; width: 33%;">Счёт: 7</td>
#     <td style="padding: 10px; width: 34%;"></td>
#   </tr>
#   <!-- 2 строка: 3 столбец яблоко -->
#   <tr>
#     <td style="padding: 10px;"></td>
#     <td style="padding: 10px;"></td>
#     <td style="padding: 10px; text-align: center;">🍎</td>
#   </tr>
#   <!-- 3 строка: 1 столбец яблоко -->
#   <tr>
#     <td style="padding: 10px; text-align: center;">🍎</td>
#     <td style="padding: 10px;"></td>
#     <td style="padding: 10px;"></td>
#   </tr>
#   <!-- 4 строка: 2 столбец яблоко -->
#   <tr>
#     <td style="padding: 10px;"></td>
#     <td style="padding: 10px; text-align: center;">🍎</td>
#     <td style="padding: 10px;"></td>
#   </tr>
#   <!-- 5 строка: 2 столбец корзина -->
#   <tr>
#     <td style="padding: 10px;"></td>
#     <td style="padding: 10px; text-align: center;">🧺</td>
#     <td style="padding: 10px;"></td>
#   </tr>
# </table>
# 1. Игрок двигает корзинку (← →). <br>
# 2. Яблоки падают сверху. <br>
#     - Поймал: +1 <br>
#     - Пропустил: -1 жизнь <br>
# 3. Игра заканчивается:<br>
# УРОЖАЙ СОБРАН!<br>
# Ты набрал X очков

# %% [markdown]
# ## Applegame v.01
# * 🍏 **Отрисовка яблок и корзинки**
# * 🏃‍♂️ **Движение яблок и корзинки**
# * 📊 **Счетчик пойманных яблок**
# * ⌨️ **Управление стрелками**
#
# ⏳ Пока нет:
# * 💔 **Счетчик жизней**
# * 🏁 **Конечность игры**

# %%
import tkinter as tk
import random

# Окно
root = tk.Tk()
root.title("Собери урожай")

WIDTH = 400
HEIGHT = 400

canvas = tk.Canvas(
    root,
    width=WIDTH,
    height=HEIGHT
)
canvas.pack()

# Фон
bg_image = tk.PhotoImage(file="img/tree.png")
bg_id = canvas.create_image(
    0,
    0,
    image=bg_image,
    anchor="nw"
)

# Счёт
score = 0

score_text = canvas.create_text(
    50,
    20,
    text="Счёт: 0",
    font=("Arial", 14)
)

# Корзинка
basket_x = 200
basket_y = 350

basket = canvas.create_text(
    basket_x,
    basket_y,
    text="🧺",
    font=("Arial", 35),
    fill="brown"
)

# Яблоко
apple_x = random.randint(30, 370)
apple_y = 50

apple = canvas.create_text(
    apple_x,
    apple_y,
    text="🍎",
    font=("Arial", 25),
    fill="red"
)

# Движение корзинки
def move_left(event):
    global basket_x

    if basket_x > 30:
        basket_x -= 20
        canvas.move(basket, -20, 0)


def move_right(event):
    global basket_x

    if basket_x < 370:
        basket_x += 20
        canvas.move(basket, 20, 0)


# Движение яблока
def move_apple():
    global apple_x, apple_y, score

    apple_y += 5
    canvas.move(apple, 0, 5)

    # Проверяем, поймала ли корзинка яблоко
    if apple_y >= 330 and abs(apple_x - basket_x) < 40:
        score += 1

        canvas.itemconfig(
            score_text,
            text=f"Счёт: {score}"
        )

        # Новое яблоко
        apple_x = random.randint(30, 370)
        apple_y = 50

        canvas.coords(
            apple,
            apple_x,
            apple_y
        )

    # Если яблоко упало — тоже создаём новое
    elif apple_y > HEIGHT:
        apple_x = random.randint(30, 370)
        apple_y = 50

        canvas.coords(
            apple,
            apple_x,
            apple_y
        )

    # Повторяем движение
    root.after(50, move_apple)


# Управление клавиатурой
root.bind("<Left>", move_left)
root.bind("<Right>", move_right)


# Запускаем игру
move_apple()

root.mainloop()

# %% [markdown]
# ## Applegame v.02
#  * 🍎 **поймал → +1**
#  * 🍎 **пропустил → −1 ❤️**
#  * 🥫 **поймал → −1 ❤️**
#  * 🥫 **пропустил → ничего**
#  * ❤️ **закончились → «УРОЖАЙ СОБРАН!»**

# %%
import tkinter as tk
import random


# Окно
root = tk.Tk()
root.title("Собери урожай")

WIDTH = 400
HEIGHT = 400

canvas = tk.Canvas(
    root,
    width=WIDTH,
    height=HEIGHT
)
canvas.pack()


# Фон
bg_image = tk.PhotoImage(file="img/tree.png")
bg_id = canvas.create_image(
    0,
    0,
    image=bg_image,
    anchor="nw"
)


# Счёт и жизни
score = 0
lives = 3
game_active = True

score_text = canvas.create_text(
    50,
    20,
    text="Счёт: 0",
    font=("Arial", 14)
)

lives_text = canvas.create_text(
    330,
    20,
    text="❤️❤️❤️",
    font=("Arial", 14),
    fill="red"
)


# Корзинка
basket_x = 200
basket_y = 350

basket = canvas.create_text(
    basket_x,
    basket_y,
    text="🧺",
    font=("Arial", 35),
    fill="brown"
)


# Падающие предметы
objects = []


# Создание яблока или мусора
def create_object():
    if not game_active:
        return

    x = random.randint(30, 370)
    y = 50

    if random.randint(1, 5) == 1:
        item = canvas.create_text(
            x,
            y,
            text="🥫",
            font=("Arial", 25),
            fill="red"
        )
        object_type = "trash"
    else:
        item = canvas.create_text(
            x,
            y,
            text="🍎",
            font=("Arial", 25),
            fill="red"
        )
        object_type = "apple"

    objects.append([item, x, y, object_type])

    root.after(1000, create_object)


# Движение корзинки
def move_left(event):
    global basket_x

    if game_active and basket_x > 30:
        basket_x -= 20
        canvas.move(basket, -20, 0)


def move_right(event):
    global basket_x

    if game_active and basket_x < 370:
        basket_x += 20
        canvas.move(basket, 20, 0)


# Потеря жизни
def lose_life():
    global lives, game_active

    lives -= 1

    canvas.itemconfig(
        lives_text,
        text="❤️" * lives
    )

    if lives <= 0:
        game_active = False
        end_game()


# Игровой цикл
def update_game():
    global score

    if not game_active:
        return

    for obj in objects[:]:

        item = obj[0]
        x = obj[1]
        y = obj[2]
        object_type = obj[3]

        # Двигаем предмет вниз
        y += 5
        obj[2] = y

        canvas.move(item, 0, 5)

        # Проверяем, поймали ли предмет
        if y >= 330 and y <= 370:

            if abs(x - basket_x) < 40:

                if object_type == "apple":
                    score += 1

                    canvas.itemconfig(
                        score_text,
                        text=f"Счёт: {score}"
                    )

                else:
                    lose_life()

                canvas.delete(item)
                objects.remove(obj)

                continue

        # Если яблоко упало мимо
        if y > HEIGHT:

            if object_type == "apple":
                lose_life()

            canvas.delete(item)
            objects.remove(obj)

    if game_active:
        root.after(50, update_game)


# Конец игры
def end_game():
    canvas.delete("all")

    canvas.create_text(
        WIDTH // 2,
        HEIGHT // 2 - 30,
        text="УРОЖАЙ СОБРАН!",
        font=("Arial", 24, "bold")
    )

    canvas.create_text(
        WIDTH // 2,
        HEIGHT // 2 + 20,
        text=f"Ты набрал {score} очков",
        font=("Arial", 16)
    )


# Управление
root.bind("<Left>", move_left)
root.bind("<Right>", move_right)


# Запуск игры
create_object()
update_game()

root.mainloop()

# %% [markdown]
# # Задание
#
# ## 🟢 Уровень 1 — Изменяем игру (5 баллов)
#
# Измени готовую игру:
#
# * изменить название игры;
# * изменить скорость падения предметов;
# * изменить размер игрового окна;
# * изменить текст, который появляется после окончания игры.
#
#
# ## 🟡 Уровень 2 — Добавляем новые возможности (8 баллов)
#
# ### Новые предметы
#
# Добавь в игру:
#
# * 🍐 **грушу** — при попадании в корзину **+2 очка**;
# * 💣 **бомбу** — при попадании в корзину **−2 очка** (Важно!!!), **−1❤️️**.
#
# ### Что можно использовать
#
# | Команда               | Что делает                                 |
# | --------------------- | ------------------------------------------ |
# | `if / elif / else`    | Выбирает действие в зависимости от условия |
# | `+=`                  | Увеличивает значение переменной            |
# | `-=`                  | Уменьшает значение переменной              |
# | `random.randint(...)` | Получает случайное целое число             |
#
#
# ### Оформление игры
#
# Сделай игру более красивой:
#
# * добавить изображения вместо смайликов для игровых объектов;
# * добавить изображение корзинки;
# * заменить изображение фона.
#
# ### Что можно использовать
#
# | Команда                     | Что делает                      |
# | --------------------------- | ------------------------------- |
# | `tk.PhotoImage(file="...")` | Загружает изображение из файла  |
# | `canvas.create_image(...)`  | Размещает изображение на Canvas |
#
#
#
# ## 🔴 Уровень 3 — Увеличиваем сложность (10 баллов)
#
# Сделай так, чтобы игра становилась сложнее по мере увеличения счёта.
#
# Например:
#
# * сначала предметы падают медленно;
# * чем больше очков набирает игрок, тем быстрее они начинают падать.
#
# ### Что можно использовать
#
# | Метод / команда              | Что делает                                               |
# | ---------------------------- | -------------------------------------------------------- |
# | `root.after(время, функция)` | Запускает функцию через указанное количество миллисекунд |
# | `if`                         | Проверяет условие                                        |
# | `score`                      | Хранит текущее количество очков                          |
#
# **Идея:** если счёт увеличивается, время между перемещениями предмета должно уменьшаться.
#
#
# ## ⚠️ Уровень 4 — Дополнительный (15 баллов - 5 баллов сверх максимума д/з)
#
# Измени правила окончания игры.
#
# Вместо трёх жизней используй **таймер на 30 секунд**.
#
# Задача игрока — за 30 секунд набрать как можно больше очков.
#
# Правила:
#
# * 🍎 яблоко → **+1 очко**;
# * 🍐 груша → **+2 очка**;
# * 🥫 банка → **−1 очко**;
# * 💣 бомба → **−2 очка**.
#
# Попробуй вывести в верхней части экрана оставшееся время.
#
# После окончания 30 секунд игра останавливается и появляется результат:
#
# > **Время вышло! Ты набрал X очков.**
#
# ### Что можно использовать
#
# | Метод / команда          | Что делает                                   |
# | ------------------------ | -------------------------------------------- |
# | `root.after(...)`        | Запускает действие через заданное время      |
# | `time`                   | Позволяет работать со временем               |
# | `time.time()`            | Возвращает текущее время                     |
# | `canvas.itemconfig(...)` | Меняет текст счётчика или таймера            |
